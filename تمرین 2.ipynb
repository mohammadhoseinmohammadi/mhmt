# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import learning_curve

# %%
x = np.random.rand(200, 1) * 100
y = 4 * x**4 - 3 *x**3 +2 *x**2 -x +1
y = y + np.random.normal(scale=3, size=y.shape)

# %%
split = int(x.shape[0] * 0.8)

x_train = x[:split]
y_train = y[:split]

x_test = x[split:]
y_test = y[split:]
x = x.reshape(-1, 1)
y = y.reshape(-1, 1)
lr_model = LinearRegression(normalize=True)

# %%
lr_model.fit(x_train, y_train)
y_line = lr_model.predict(x_test)
print(lr_model.score(x_train, y_train))

print(lr_model.score(x_test, y_test))
plt.plot(x_train, y_train, 'bo')
plt.plot(x_test, y_test, 'co')
plt.plot(x_test, y_line, 'r--')
h1=lr_model.predict(x_train)
h2=lr_model.predict(x_test)
M1=np.mean((y_train - h1) ** 2) / 2
M2=np.mean((y_test - h2) ** 2) / 2
print(np.mean((y_train - h1) ** 2) / 2)
print(np.mean((y_test - h2) ** 2) / 2)
# Out:
# 0.7196903745816301
# 0.7388471034475776
# 1543694105312283.5
# 1183262163170773.2

# %%
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LinearRegression(),
X = x_train,
y = y_train, cv = 5,
scoring = 'neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a linear regression model', fontsize = 18, y = 1.03)
plt.legend()

# %%
x_4 = np.hstack((x_train, x_train ** 2))
lr_model.fit(x_4, y_train)
x_line = np.arange(-10, 110, 0.1).reshape(-1, 1)
x_line_poly = np.hstack((x_line, x_line ** 2))
y_line = lr_model.predict(x_line_poly)
x_5 = np.hstack((x_test, x_test ** 2))
plt.plot(x_train, y_train, 'bo')
plt.plot(x_test, y_test, 'co')
plt.plot(x_line, y_line, 'r--')
print(lr_model.score(x_4, y_train))
print(lr_model.score(x_5, y_test))
h3=lr_model.predict(x_4)
h4=lr_model.predict(x_5)
M3=np.mean((y_train - h3) ** 2) / 2
M4=np.mean((y_test - h4) ** 2) / 2
print(np.mean((y_train - h3) ** 2) / 2)
print(np.mean((y_test - h4) ** 2) / 2)
# Out:
# 0.9783855034102485
# 0.9740608623934309
# 119033268747342.72
# 117528085961597.28

# %%
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LinearRegression(),
X = x_4,
y = y_train, cv = 5,
scoring = 'neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a linear regression model', fontsize = 18, y = 1.03)
plt.legend()

# %%
x_4 = np.hstack((x_train, x_train ** 2, x_train ** 3, x_train ** 4))
lr_model.fit(x_4, y_train)
x_line = np.arange(-10, 110, 0.1).reshape(-1, 1)
x_line_poly = np.hstack((x_line, x_line ** 2, x_line ** 3, x_line ** 4))
y_line = lr_model.predict(x_line_poly)
x_5 = np.hstack((x_test, x_test ** 2, x_test ** 3, x_test ** 4))
plt.plot(x_train, y_train, 'bo')
plt.plot(x_test, y_test, 'co')
plt.plot(x_line, y_line, 'r--')
print(lr_model.score(x_4, y_train))
print(lr_model.score(x_5, y_test))
h5=lr_model.predict(x_4)
h6=lr_model.predict(x_5)
M5=np.mean((y_train - h5) ** 2) / 2
M6=np.mean((y_test - h6) ** 2) / 2
print(np.mean((y_train - h5) ** 2) / 2)
print(np.mean((y_test - h6) ** 2) / 2)
# Out:
# 0.9999999999999991
# 0.9999999999999988
# 4.669392526784618
# 5.4747060982160844

# %%
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LinearRegression(),
X = x_4,
y = y_train, cv = 5,
scoring = 'neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a linear regression model', fontsize = 18, y = 1.03)
plt.legend()

# %%
x_4 = np.hstack((x_train, x_train ** 2, x_train ** 3, x_train ** 4, x_train ** 5, x_train ** 6, x_train ** 7, x_train ** 8))
lr_model.fit(x_4, y_train)
x_line = np.arange(-10, 110, 0.1).reshape(-1, 1)
x_line_poly = np.hstack((x_line, x_line ** 2, x_line ** 3, x_line ** 4, x_line ** 5, x_line ** 6, x_line ** 7, x_line ** 8))
y_line = lr_model.predict(x_line_poly)
x_5 = np.hstack((x_test, x_test ** 2, x_test ** 3, x_test ** 4, x_test ** 5, x_test ** 6, x_test ** 7, x_test ** 8))
plt.plot(x_train, y_train, 'bo')
plt.plot(x_test, y_test, 'co')
plt.plot(x_line, y_line, 'r--')
print(lr_model.score(x_4, y_train))
print(lr_model.score(x_5, y_test))
h7=lr_model.predict(x_4)
h8=lr_model.predict(x_5)
M7=np.mean((y_train - h7) ** 2) / 2
M8=np.mean((y_test - h8) ** 2) / 2
print(np.mean((y_train - h7) ** 2) / 2)
print(np.mean((y_test - h8) ** 2) / 2)
# Out:
# 0.9999999999999992
# 0.9999999999999986
# 4.371452741839943
# 5.872525698349863

# %%
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LinearRegression(),
X = x_4,
y = y_train, cv = 5,
scoring = 'neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a linear regression model', fontsize = 18, y = 1.03)
plt.legend()

# %%
x_4 = np.hstack((x_train, x_train ** 2, x_train ** 3, x_train ** 4, x_train ** 5, x_train ** 6, x_train ** 7, x_train ** 8, x_train ** 9, x_train ** 10, x_train ** 11, x_train ** 12, x_train ** 13, x_train ** 14, x_train ** 15, x_train ** 16))
lr_model.fit(x_4, y_train)
x_line = np.arange(-10, 110, 0.1).reshape(-1, 1)
x_line_poly = np.hstack((x_line, x_line ** 2, x_line ** 3, x_line ** 4, x_line ** 5, x_line ** 6, x_line ** 7, x_line ** 8, x_line ** 9, x_line ** 10, x_line ** 11, x_line ** 12, x_line ** 13, x_line ** 14, x_line ** 15, x_line ** 16))
y_line = lr_model.predict(x_line_poly)
x_5 = np.hstack((x_test, x_test ** 2, x_test ** 3, x_test ** 4, x_test ** 5, x_test ** 6, x_test ** 7, x_test ** 8, x_test ** 9, x_test ** 10, x_test ** 11, x_test ** 12, x_test ** 13, x_test ** 14, x_test ** 15, x_test ** 16))
plt.plot(x_train, y_train, 'bo')
plt.plot(x_test, y_test, 'co')
plt.plot(x_line, y_line, 'r--')
print(lr_model.score(x_4, y_train))
print(lr_model.score(x_5, y_test))
h9=lr_model.predict(x_4)
h10=lr_model.predict(x_5)
M9=np.mean((y_train - h9) ** 2) / 2
M10=np.mean((y_test - h10) ** 2) / 2
print(np.mean((y_train - h9) ** 2) / 2)
print(np.mean((y_test - h10) ** 2) / 2)
# Out:
# 0.9999999999999992
# 0.9999999999999986
# 4.12086027567912
# 6.1293707403831545

# %%
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LinearRegression(),
X = x_4,
y = y_train, cv = 5,
scoring = 'neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a linear regression model', fontsize = 18, y = 1.03)
plt.legend()

# %%
power=[1,2,4,8,16]
train=[M1,M3,M5,M7,M9]
test=[M2,M4,M6,M8,M10]
plt.plot(power, train, 'b--')
plt.plot(power, test, 'r--')
